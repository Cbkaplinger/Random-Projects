# %%
from pybaseball import statcast
from pybaseball import pitching_stats_bref
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
savant_df = statcast(start_dt = "2023-03-30", end_dt = "2023-11-15")
#pd.set_option('display.max_columns', None)

savant_df
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 231/231 [01:05<00:00,  3.54it/s]
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1256         SL 2023-09-21           91.2          -1.52           5.61
# 1281         SL 2023-09-21           87.1          -1.49           5.63
# 1302         FF 2023-09-21           98.5          -1.43           5.75
# 1336         SL 2023-09-21           86.8          -1.58           5.63
# 1373         FF 2023-09-21           98.4           -1.3           5.86
# ...         ...        ...            ...            ...            ...
# 3827         SI 2023-03-30           95.3          -3.11           5.24
# 4071         FF 2023-03-30           94.2          -3.16           5.29
# 4229         FF 2023-03-30           94.8          -3.12            5.3
# 4332         SI 2023-03-30           95.1           -3.2           5.22
# 4515         FF 2023-03-30           95.1          -3.31           5.27
#
#           player_name  batter  pitcher  events    description  ...  fld_score  \
# 1256  Estévez, Carlos  622534   608032  single  hit_into_play  ...          4
# 1281  Estévez, Carlos  622534   608032    None           foul  ...          4
# 1302  Estévez, Carlos  622534   608032    None           ball  ...          4
# 1336  Estévez, Carlos  622534   608032    None           foul  ...          4
# 1373  Estévez, Carlos  666139   608032    walk           ball  ...          4
# ...               ...     ...      ...     ...            ...  ...        ...
# 3827   Castillo, Luis  680757   622491    None  called_strike  ...          0
# 4071   Castillo, Luis  680757   622491    None  called_strike  ...          0
# 4229   Castillo, Luis  680757   622491    None           ball  ...          0
# 4332   Castillo, Luis  680757   622491    None           ball  ...          0
# 4515   Castillo, Luis  680757   622491    None           ball  ...          0
#
#       post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 1256                4                5               5               4
# 1281                4                4               4               4
# 1302                4                4               4               4
# 1336                4                4               4               4
# 1373                4                4               4               4
# ...               ...              ...             ...             ...
# 3827                0                0               0               0
# 4071                0                0               0               0
# 4229                0                0               0               0
# 4332                0                0               0               0
# 4515                0                0               0               0
#
#      if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 1256              Standard              Standard       155              0.342
# 1281              Standard              Standard       136                0.0
# 1302              Standard              Standard       199                0.0
# 1336              Standard              Standard       136                0.0
# 1373              Standard              Standard       201              0.047
# ...                    ...                   ...       ...                ...
# 3827              Standard              Standard       234                0.0
# 4071              Standard             Strategic       229                0.0
# 4229              Standard             Strategic       233                0.0
# 4332              Standard              Standard       237                0.0
# 4515              Standard              Standard       237                0.0
#
#      delta_run_exp
# 1256         1.779
# 1281        -0.232
# 1302           0.1
# 1336        -0.138
# 1373         0.232
# ...            ...
# 3827        -0.081
# 4071        -0.077
# 4229         0.136
# 4332         0.064
# 4515         0.036
#
# [677862 rows x 92 columns]

# %%
# Converts the Induced Vertical Break and Horizontal Break to inches from feet
savant_df['IVB'] = savant_df['pfx_z'] * 12
savant_df['HB'] = savant_df['pfx_x'] * 12

savant_df = savant_df.rename(columns={'player_name': 'Name', 'pitch_type': 'Pitch Type'})
savant_df
# Out:
#      Pitch Type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1256         SL 2023-09-21           91.2          -1.52           5.61
# 1281         SL 2023-09-21           87.1          -1.49           5.63
# 1302         FF 2023-09-21           98.5          -1.43           5.75
# 1336         SL 2023-09-21           86.8          -1.58           5.63
# 1373         FF 2023-09-21           98.4           -1.3           5.86
# ...         ...        ...            ...            ...            ...
# 3827         SI 2023-03-30           95.3          -3.11           5.24
# 4071         FF 2023-03-30           94.2          -3.16           5.29
# 4229         FF 2023-03-30           94.8          -3.12            5.3
# 4332         SI 2023-03-30           95.1           -3.2           5.22
# 4515         FF 2023-03-30           95.1          -3.31           5.27
#
#                  Name  batter  pitcher  events    description  ...  \
# 1256  Estévez, Carlos  622534   608032  single  hit_into_play  ...
# 1281  Estévez, Carlos  622534   608032    None           foul  ...
# 1302  Estévez, Carlos  622534   608032    None           ball  ...
# 1336  Estévez, Carlos  622534   608032    None           foul  ...
# 1373  Estévez, Carlos  666139   608032    walk           ball  ...
# ...               ...     ...      ...     ...            ...  ...
# 3827   Castillo, Luis  680757   622491    None  called_strike  ...
# 4071   Castillo, Luis  680757   622491    None  called_strike  ...
# 4229   Castillo, Luis  680757   622491    None           ball  ...
# 4332   Castillo, Luis  680757   622491    None           ball  ...
# 4515   Castillo, Luis  680757   622491    None           ball  ...
#
#       post_home_score  post_bat_score  post_fld_score  if_fielding_alignment  \
# 1256                5               5               4               Standard
# 1281                4               4               4               Standard
# 1302                4               4               4               Standard
# 1336                4               4               4               Standard
# 1373                4               4               4               Standard
# ...               ...             ...             ...                    ...
# 3827                0               0               0               Standard
# 4071                0               0               0               Standard
# 4229                0               0               0               Standard
# 4332                0               0               0               Standard
# 4515                0               0               0               Standard
#
#       of_fielding_alignment spin_axis delta_home_win_exp delta_run_exp    IVB  \
# 1256               Standard       155              0.342         1.779    3.0
# 1281               Standard       136                0.0        -0.232   -0.6
# 1302               Standard       199                0.0           0.1  17.04
# 1336               Standard       136                0.0        -0.138  -1.56
# 1373               Standard       201              0.047         0.232  15.96
# ...                     ...       ...                ...           ...    ...
# 3827               Standard       234                0.0        -0.081   5.52
# 4071              Strategic       229                0.0        -0.077  13.92
# 4229              Strategic       233                0.0         0.136  14.28
# 4332               Standard       237                0.0         0.064   4.92
# 4515               Standard       237                0.0         0.036  14.88
#
#          HB
# 1256   6.48
# 1281   4.56
# 1302  -8.88
# 1336   3.84
# 1373   -6.6
# ...     ...
# 3827 -20.28
# 4071 -15.36
# 4229   -9.6
# 4332 -20.52
# 4515 -14.52
#
# [677862 rows x 94 columns]

# %%
def flip_names(name):
    first_name, last_name = name.split(", ")
    return f"{last_name} {first_name}"

savant_df['Name'] = savant_df["Name"].apply(flip_names)

# %%
player_grouped = savant_df.groupby(['Name']).agg(
    Pitches = ('Pitch Type', 'count'),
    BB = ('events', lambda x: (x == 'walk').sum()),
    HBP = ('events', lambda x: (x == 'hit_by_pitch').sum()),
    K = ('events', lambda x: (x == 'strikeout').sum()),
    TBF = ('events', lambda x: (x.isin(['other_out', 'single', 'double', 'triple', 'home_run', 'walk', 'strikeout', 'field_out', 'hit_by_pitch', 'sac_fly', 'sac_fly_double_play', 'sac_bunt', 'field_error', 'fielders_choice', 'double_play', 'fielders_choice_out', 'sac_fly_double_play', 'strikeout_double_play', 'catcher_interf', 'triple_play', 'grounded_into_double_play'])).sum()),
    GB = ('bb_type', lambda x: (x == 'ground_ball').sum()),
    LD = ('bb_type', lambda x: (x == 'line_drive').sum()),
    FB = ('bb_type', lambda x: (x == 'fly_ball').sum()),
    PU = ('bb_type', lambda x: (x == 'popup').sum()),
    BIP = ('bb_type', lambda x: (x.isin(['ground_ball', 'line_drive', 'fly_ball', 'popup'])).sum()),
    xwOBA = ('estimated_woba_using_speedangle', 'mean'),
    Run_Value = ('delta_run_exp', 'sum'),
    CS_Percent = ('description', lambda x: round((x == 'called_strike').mean() * 100, 2)),
    SwStr_Percent = ('description', lambda x: round((x.isin(['swinging_strike', 'swinging_strike_blocked'])).mean() * 100, 2)))

player_grouped['xwOBA'] = round(player_grouped['xwOBA'], 3)
player_grouped = player_grouped.rename(columns = {"CS_Percent": "CS%", "SwStr_Percent": "SwStr%"})
player_grouped['CSW%'] = player_grouped['SwStr%'] + player_grouped['CS%']
player_grouped['GB%'] = round((player_grouped['GB'] / player_grouped['BIP']) * 100, 2)
player_grouped['K%'] = round((player_grouped['K'] / player_grouped['TBF']) * 100, 2)
player_grouped['BB%'] = round((player_grouped['BB'] / player_grouped['TBF']) * 100, 2)
player_grouped['K-BB%'] = round((player_grouped['K%'] - player_grouped['BB%']), 2)

player_grouped = player_grouped[player_grouped['TBF'] >= 350]
player_grouped
# Out:
#                  Pitches  BB  HBP    K  TBF   GB   LD   FB  PU  BIP  xwOBA  \
# Name
# Aaron Civale        1969  31    5  113  485  137   83   95  30  345  0.354
# Aaron Nola          2997  45    1  190  756  226  133  138  33  530  0.377
# Adam Wainwright     1785  40    1   55  469  159  104  110  14  387  0.421
# Adrian Houser       1704  30    1   85  432  154   71   83  16  324  0.366
# Alek Manoah         1689  56    9   79  405  104   65   78  21  268  0.402
# ...                  ...  ..  ...  ...  ...  ...  ...  ...  ..  ...    ...
# Zac Gallen          3053  44    5  201  782  224  148  147  24  543  0.398
# Zach Davies         1425  38    2   69  353  112   63   62  13  250  0.388
# Zach Eflin          2506  23    3  181  670  237   98  104  35  474  0.345
# Zack Greinke        2074  20    4   88  546  194  111  114  25  444  0.392
# Zack Wheeler        2989  37    8  200  728  204  115  130  45  494  0.352
#
#                  Run_Value    CS%  SwStr%   CSW%    GB%     K%    BB%  K-BB%
# Name
# Aaron Civale       -18.447  18.99   10.11  29.10  39.71  23.30   6.39  16.91
# Aaron Nola           4.117  18.08   11.81  29.89  42.64  25.13   5.95  19.18
# Adam Wainwright     35.894  19.61    4.93  24.54  41.09  11.73   8.53   3.20
# Adrian Houser        1.228  18.60    7.04  25.64  47.53  19.68   6.94  12.74
# Alek Manoah         20.603  15.39    8.82  24.21  38.81  19.51  13.83   5.68
# ...                    ...    ...     ...    ...    ...    ...    ...    ...
# Zac Gallen         -22.989  17.10   11.17  28.27  41.25  25.70   5.63  20.07
# Zach Davies         17.677  18.39    7.93  26.32  44.80  19.55  10.76   8.79
# Zach Eflin         -19.783  19.03   11.21  30.24  50.00  27.01   3.43  23.58
# Zack Greinke        16.431  17.45    7.14  24.59  43.69  16.12   3.66  12.46
# Zack Wheeler       -21.074  14.32   13.32  27.64  41.30  27.47   5.08  22.39
#
# [150 rows x 19 columns]

# %%
# Creation of my stat Simple Predicted Run Average
K = -0.216668
BB = 0.218963
FB = 0.100319
GB = -0.061018
LD = 0.295364
PU = -0.231931
HBP = 0.373525

# Creation of my stat Simple Predicted Run Average
player_grouped["sPRA"] = round(
    ((0.85 * (BB * 16.38860664066341 * player_grouped["BB"]) + (HBP * 16.38860664066341 * player_grouped["HBP"]) + (K * 16.38860664066341 * player_grouped["K"]) + 
    (FB * 16.38860664066341 * player_grouped["FB"]) + (LD * 16.38860664066341 * player_grouped["LD"]) + (PU * 16.38860664066341 * player_grouped["PU"]) + (GB * 16.38860664066341 * player_grouped["GB"]))
    / player_grouped["TBF"]) + 4.05, 2)
player_grouped = player_grouped.sort_values(by = "sPRA")
player_grouped = player_grouped.reset_index()
player_grouped
# Out:
#                  Name  Pitches  BB  HBP    K  TBF   GB   LD   FB  PU  ...  \
# 0     Spencer Strider     2898  53    9  270  699  130   94  125  31  ...
# 1       Tyler Glasnow     1723  32    1  146  442  133   59   63  11  ...
# 2      Freddy Peralta     2769  54    6  206  650  170   80  107  39  ...
# 3          Zach Eflin     2506  23    3  181  670  237   98  104  35  ...
# 4       Shohei Ohtani     2094  55   11  167  524  136   61   76  24  ...
# ..                ...      ...  ..  ...  ...  ...  ...  ...  ...  ..  ...
# 145   Carlos Carrasco     1587  38    6   66  406  140   87   66  14  ...
# 146    Connor Seabold     1467  26    7   62  382   93   77   97  22  ...
# 147     Cal Quantrill     1516  30    6   50  390  125   83   80  24  ...
# 148  Noah Syndergaard     1408  19   10   56  386  117   86   85  18  ...
# 149   Adam Wainwright     1785  40    1   55  469  159  104  110  14  ...
#
#      xwOBA  Run_Value    CS%  SwStr%   CSW%    GB%     K%    BB%  K-BB%  sPRA
# 0    0.391    -17.223  14.98   19.37  34.35  34.21  38.63   7.58  31.05  3.58
# 1     0.42    -10.961  16.54   16.60  33.14  50.00  33.03   7.24  25.79  3.60
# 2    0.358    -13.657  15.28   14.37  29.65  42.93  31.69   8.31  23.38  3.61
# 3    0.345    -19.783  19.03   11.21  30.24  50.00  27.01   3.43  23.58  3.63
# 4    0.383    -17.062  17.19   12.89  30.08  45.79  31.87  10.50  21.37  3.74
# ..     ...        ...    ...     ...    ...    ...    ...    ...    ...   ...
# 145  0.425     20.766  15.12   11.03  26.15  45.60  16.26   9.36   6.90  4.68
# 146  0.388     33.431  15.68    9.88  25.56  32.18  16.23   6.81   9.42  4.72
# 147  0.382      9.846  14.71    7.59  22.30  40.06  12.82   7.69   5.13  4.74
# 148   0.42     16.229  16.69    8.17  24.86  38.24  14.51   4.92   9.59  4.80
# 149  0.421     35.894  19.61    4.93  24.54  41.09  11.73   8.53   3.20  4.91
#
# [150 rows x 21 columns]
