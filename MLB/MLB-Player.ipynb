# %%
from pybaseball import statcast
from pybaseball import pitching_stats_bref
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
savant_df = statcast(start_dt = "2023-03-30", end_dt = "2023-11-15")
#pd.set_option('display.max_columns', None)

savant_df
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 231/231 [01:38<00:00,  2.35it/s]
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 121          CU 2023-11-01           84.9          -1.19           6.12
# 123          FF 2023-11-01           96.6          -0.69           6.24
# 128          CU 2023-11-01           84.5          -1.27           6.11
# 131          FF 2023-11-01           95.4           -0.8           6.23
# 137          FF 2023-11-01           95.6          -0.83           6.19
# ...         ...        ...            ...            ...            ...
# 3812         SI 2023-03-30           95.3          -3.11           5.24
# 3998         FF 2023-03-30           94.2          -3.16           5.29
# 4114         FF 2023-03-30           94.8          -3.12            5.3
# 4316         SI 2023-03-30           95.1           -3.2           5.22
# 4471         FF 2023-03-30           95.1          -3.31           5.27
#
#          player_name  batter  pitcher     events    description  ...  \
# 121      Sborz, Josh  606466   622250  strikeout  called_strike  ...
# 123      Sborz, Josh  606466   622250        NaN           ball  ...
# 128      Sborz, Josh  606466   622250        NaN  called_strike  ...
# 131      Sborz, Josh  606466   622250        NaN           foul  ...
# 137      Sborz, Josh  606466   622250        NaN           ball  ...
# ...              ...     ...      ...        ...            ...  ...
# 3812  Castillo, Luis  680757   622491       None  called_strike  ...
# 3998  Castillo, Luis  680757   622491       None  called_strike  ...
# 4114  Castillo, Luis  680757   622491       None           ball  ...
# 4316  Castillo, Luis  680757   622491       None           ball  ...
# 4471  Castillo, Luis  680757   622491       None           ball  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 121           5                5                0               0
# 123           5                5                0               0
# 128           5                5                0               0
# 131           5                5                0               0
# 137           5                5                0               0
# ...         ...              ...              ...             ...
# 3812          0                0                0               0
# 3998          0                0                0               0
# 4114          0                0                0               0
# 4316          0                0                0               0
# 4471          0                0                0               0
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 121                5         Infield shade              Standard        26
# 123                5             Strategic              Standard       206
# 128                5              Standard              Standard        24
# 131                5              Standard              Standard       204
# 137                5              Standard              Standard       207
# ...              ...                   ...                   ...       ...
# 3812               0              Standard              Standard       234
# 3998               0              Standard             Strategic       229
# 4114               0              Standard             Strategic       233
# 4316               0              Standard              Standard       237
# 4471               0              Standard              Standard       237
#
#      delta_home_win_exp delta_run_exp
# 121                 0.0         -0.09
# 123                 0.0         0.016
# 128                 0.0        -0.027
# 131                 0.0        -0.022
# 137                 0.0         0.016
# ...                 ...           ...
# 3812                0.0        -0.079
# 3998                0.0        -0.078
# 4114                0.0         0.135
# 4316                0.0         0.064
# 4471                0.0         0.036
#
# [729774 rows x 92 columns]

# %%
# Converts the Induced Vertical Break and Horizontal Break to inches from feet
savant_df['IVB'] = savant_df['pfx_z'] * 12
savant_df['HB'] = savant_df['pfx_x'] * 12

savant_df = savant_df.rename(columns={'player_name': 'Name', 'pitch_type': 'Pitch Type'})
savant_df
# Out:
#      Pitch Type  game_date  release_speed  release_pos_x  release_pos_z  \
# 121          CU 2023-11-01           84.9          -1.19           6.12
# 123          FF 2023-11-01           96.6          -0.69           6.24
# 128          CU 2023-11-01           84.5          -1.27           6.11
# 131          FF 2023-11-01           95.4           -0.8           6.23
# 137          FF 2023-11-01           95.6          -0.83           6.19
# ...         ...        ...            ...            ...            ...
# 3812         SI 2023-03-30           95.3          -3.11           5.24
# 3998         FF 2023-03-30           94.2          -3.16           5.29
# 4114         FF 2023-03-30           94.8          -3.12            5.3
# 4316         SI 2023-03-30           95.1           -3.2           5.22
# 4471         FF 2023-03-30           95.1          -3.31           5.27
#
#                 Name  batter  pitcher     events    description  ...  \
# 121      Sborz, Josh  606466   622250  strikeout  called_strike  ...
# 123      Sborz, Josh  606466   622250        NaN           ball  ...
# 128      Sborz, Josh  606466   622250        NaN  called_strike  ...
# 131      Sborz, Josh  606466   622250        NaN           foul  ...
# 137      Sborz, Josh  606466   622250        NaN           ball  ...
# ...              ...     ...      ...        ...            ...  ...
# 3812  Castillo, Luis  680757   622491       None  called_strike  ...
# 3998  Castillo, Luis  680757   622491       None  called_strike  ...
# 4114  Castillo, Luis  680757   622491       None           ball  ...
# 4316  Castillo, Luis  680757   622491       None           ball  ...
# 4471  Castillo, Luis  680757   622491       None           ball  ...
#
#       post_home_score  post_bat_score  post_fld_score  if_fielding_alignment  \
# 121                 0               0               5          Infield shade
# 123                 0               0               5              Strategic
# 128                 0               0               5               Standard
# 131                 0               0               5               Standard
# 137                 0               0               5               Standard
# ...               ...             ...             ...                    ...
# 3812                0               0               0               Standard
# 3998                0               0               0               Standard
# 4114                0               0               0               Standard
# 4316                0               0               0               Standard
# 4471                0               0               0               Standard
#
#       of_fielding_alignment spin_axis delta_home_win_exp delta_run_exp    IVB  \
# 121                Standard        26                0.0         -0.09  -10.8
# 123                Standard       206                0.0         0.016   17.4
# 128                Standard        24                0.0        -0.027 -10.44
# 131                Standard       204                0.0        -0.022  18.72
# 137                Standard       207                0.0         0.016  20.04
# ...                     ...       ...                ...           ...    ...
# 3812               Standard       234                0.0        -0.079   5.52
# 3998              Strategic       229                0.0        -0.078  13.92
# 4114              Strategic       233                0.0         0.135  14.28
# 4316               Standard       237                0.0         0.064   4.92
# 4471               Standard       237                0.0         0.036  14.88
#
#          HB
# 121   13.68
# 123    -4.2
# 128   12.72
# 131   -7.56
# 137   -1.68
# ...     ...
# 3812 -20.28
# 3998 -15.36
# 4114   -9.6
# 4316 -20.52
# 4471 -14.52
#
# [729774 rows x 94 columns]

# %%
def flip_names(name):
    first_name, last_name = name.split(", ")
    return f"{last_name} {first_name}"

savant_df['Name'] = savant_df["Name"].apply(flip_names)

# %%
player_grouped = savant_df.groupby(['Name']).agg(
    Pitches = ('Pitch Type', 'count'),
    BB = ('events', lambda x: (x == 'walk').sum()),
    HBP = ('events', lambda x: (x == 'hit_by_pitch').sum()),
    K = ('events', lambda x: (x == 'strikeout').sum()),
    TBF = ('events', lambda x: (x.isin(['other_out', 'single', 'double', 'triple', 'home_run', 'walk', 'strikeout', 'field_out', 'hit_by_pitch', 'sac_fly', 'sac_fly_double_play', 'sac_bunt', 'field_error', 'fielders_choice', 'double_play', 'fielders_choice_out', 'sac_fly_double_play', 'strikeout_double_play', 'catcher_interf', 'triple_play', 'grounded_into_double_play'])).sum()),
    GB = ('bb_type', lambda x: (x == 'ground_ball').sum()),
    LD = ('bb_type', lambda x: (x == 'line_drive').sum()),
    FB = ('bb_type', lambda x: (x == 'fly_ball').sum()),
    PU = ('bb_type', lambda x: (x == 'popup').sum()),
    BIP = ('description', lambda x: (x == "hit_into_play").sum()),
    xwOBA = ('estimated_woba_using_speedangle', 'mean'),
    Run_Value = ('delta_run_exp', 'sum'),
    CS_Percent = ('description', lambda x: round((x == 'called_strike').mean() * 100, 2)),
    SwStr_Percent = ('description', lambda x: round((x.isin(['swinging_strike', 'swinging_strike_blocked'])).mean() * 100, 2)))

player_grouped['xwOBA'] = round(player_grouped['xwOBA'], 3)
player_grouped = player_grouped.rename(columns = {"CS_Percent": "CS%", "SwStr_Percent": "SwStr%"})
player_grouped['CSW%'] = player_grouped['SwStr%'] + player_grouped['CS%']
player_grouped['GB%'] = round((player_grouped['GB'] / player_grouped['BIP']) * 100, 2)
player_grouped['K%'] = round((player_grouped['K'] / player_grouped['TBF']) * 100, 2)
player_grouped['BB%'] = round((player_grouped['BB'] / player_grouped['TBF']) * 100, 2)
player_grouped['K-BB%'] = round((player_grouped['K%'] - player_grouped['BB%']), 2)

player_grouped = player_grouped[player_grouped['TBF'] >= 350]
player_grouped
# Out:
#                  Pitches  BB  HBP    K  TBF   GB   LD   FB  PU  BIP  xwOBA  \
# Name
# Aaron Civale        2009  33    5  116  494  139   83   96  31  349  0.353
# Aaron Nola          3431  49    2  221  864  265  147  155  39  606  0.374
# Adam Wainwright     1785  40    1   55  469  159  104  110  14  387  0.423
# Adrian Houser       1856  34    1   95  472  165   72   95  18  350  0.363
# Alek Manoah         1689  56    9   79  405  104   65   78  21  268    0.4
# ...                  ...  ..  ...  ...  ...  ...  ...  ...  ..  ...    ...
# Zach Davies         1498  39    2   72  371  117   69   65  13  264  0.398
# Zach Eflin          2652  24    3  188  713  253  106  113  37  509  0.356
# Zack Greinke        2219  23    4   95  580  205  118  121  25  469  0.394
# Zack Littell        1367  11    5   77  381  122   69   79  21  291  0.377
# Zack Wheeler        3557  42    9  245  877  246  136  151  59  592  0.349
#
#                  Run_Value    CS%  SwStr%   CSW%    GB%     K%    BB%  K-BB%
# Name
# Aaron Civale       -17.549  18.82   10.10  28.92  39.83  23.48   6.68  16.80
# Aaron Nola          -2.849  17.90   11.92  29.82  43.73  25.58   5.67  19.91
# Adam Wainwright     35.995  19.61    4.93  24.54  41.09  11.73   8.53   3.20
# Adrian Houser       -0.014  18.70    7.22  25.92  47.14  20.13   7.20  12.93
# Alek Manoah         20.674  15.39    8.82  24.21  38.81  19.51  13.83   5.68
# ...                    ...    ...     ...    ...    ...    ...    ...    ...
# Zach Davies         20.649  18.36    8.21  26.57  44.32  19.41  10.51   8.90
# Zach Eflin         -16.157  18.97   11.12  30.09  49.71  26.37   3.37  23.00
# Zack Greinke        14.205  17.53    7.08  24.61  43.71  16.38   3.97  12.41
# Zack Littell        -8.998  15.65   10.75  26.40  41.92  20.21   2.89  17.32
# Zack Wheeler       -27.524  14.42   13.75  28.17  41.55  27.94   4.79  23.15
#
# [164 rows x 19 columns]

# %%
# Creation of my stat Simple Predicted Run Average
K = -0.216668
BB = 0.218963
FB = 0.100319
GB = -0.061018
LD = 0.295364
PU = -0.231931
HBP = 0.373525

# Creation of my stat Simple Predicted Run Average
player_grouped["sPRA"] = round(
    ((0.85 * (BB * 16.38860664066341 * player_grouped["BB"]) + (HBP * 16.38860664066341 * player_grouped["HBP"]) + (K * 16.38860664066341 * player_grouped["K"]) + 
    (FB * 16.38860664066341 * player_grouped["FB"]) + (LD * 16.38860664066341 * player_grouped["LD"]) + (PU * 16.38860664066341 * player_grouped["PU"]) + (GB * 16.38860664066341 * player_grouped["GB"]))
    / player_grouped["TBF"]) + 4.05, 2)
player_grouped = player_grouped.sort_values(by = "sPRA")
player_grouped = player_grouped.reset_index()
player_grouped
# Out:
#                  Name  Pitches  BB  HBP    K  TBF   GB   LD   FB  PU  ...  \
# 0       Tyler Glasnow     1992  42    1  170  509  151   67   69  13  ...
# 1      Freddy Peralta     2924  56    6  215  687  179   84  118  41  ...
# 2     Spencer Strider     3290  61   10  296  798  160  112  142  32  ...
# 3          Zach Eflin     2652  24    3  188  713  253  106  113  37  ...
# 4       Shohei Ohtani     2094  55   11  167  524  136   61   76  24  ...
# ..                ...      ...  ..  ...  ...  ...  ...  ...  ...  ..  ...
# 159    Chase Anderson     1447  33    7   64  365   97   64   93  14  ...
# 160     Luis L. Ortiz     1462  48    2   59  386  141   71   74   5  ...
# 161     Cal Quantrill     1710  35    7   57  432  139   95   85  25  ...
# 162  Noah Syndergaard     1408  19   10   56  386  117   86   85  18  ...
# 163   Adam Wainwright     1785  40    1   55  469  159  104  110  14  ...
#
#      xwOBA  Run_Value    CS%  SwStr%   CSW%    GB%     K%    BB%  K-BB%  sPRA
# 0    0.405    -12.638  17.07   16.37  33.44  50.33  33.40   8.25  25.15  3.59
# 1    0.363     -9.112  15.25   14.23  29.48  42.42  31.30   8.15  23.15  3.63
# 2      0.4    -14.921  14.80   19.15  33.95  35.87  37.09   7.64  29.45  3.66
# 3    0.356    -16.157  18.97   11.12  30.09  49.71  26.37   3.37  23.00  3.67
# 4    0.384    -16.752  17.19   12.89  30.08  45.79  31.87  10.50  21.37  3.74
# ..     ...        ...    ...     ...    ...    ...    ...    ...    ...   ...
# 159  0.365      6.283  14.44    9.19  23.63  36.19  17.53   9.04   8.49  4.68
# 160  0.415      7.199  15.12    9.37  24.49  48.45  15.28  12.44   2.84  4.71
# 161  0.385     10.624  14.74    8.01  22.75  40.41  13.19   8.10   5.09  4.77
# 162  0.419     16.418  16.69    8.17  24.86  38.24  14.51   4.92   9.59  4.80
# 163  0.423     35.995  19.61    4.93  24.54  41.09  11.73   8.53   3.20  4.91
#
# [164 rows x 21 columns]
